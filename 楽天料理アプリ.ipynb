# %%
# ライブラリrequestsを使うためにimportすることで機能を使う事が出来ます。
import requests

# %%
# アクセス先を指定。
# アクセス先を指定する必要があるので、アクセス先をREQUEST_URLという変数に代入しておきます。
REQUEST_URL = 'https://app.rakuten.co.jp/services/api/Recipe/CategoryList/20170426?'


# 認証IDを指定
# アクセスを許可されたユーザーという事を証明するために、APP_IDに認証IDを代入しておきます。
APP_ID = "1042255002923493931"

# アクセス先と認証を用意できたので、なんのデータが欲しいか（要求するデータの）をparamsに代入しておきます。
# paramsでの指定方法はAPIの作成者によって変わりますので、事前に確認しておく必要があります。
params = {
    'format':'json',
    'applicationId': APP_ID    
}


# アクセス先と認証と要求するデータの内容を指定出来たので、次はrequestsのgetメソッドを使ってアクセスします。

# %%
# requestsのgetメソッドを使ってアクセス
# その結果をresに代入します。
res = requests.get(REQUEST_URL, params)

# 欲しいデータはresのjsonに格納されているので、res.json()をresultに代入しておきましょう。
result = res.json()

# これでAPIで取得したデータはresultに代入されます。
result
# Out:
# {'result': {'large': [{'categoryId': '30',
#     'categoryName': '人気メニュー',
#     'categoryUrl': 'https://recipe.rakuten.co.jp/category/30/?rafcid=wsc_r_cl_1042255002923493931'},
#    {'categoryId': '31',
#     'categoryName': '定番の肉料理',
#     'categoryUrl': 'https://recipe.rakuten.co.jp/category/31/?rafcid=wsc_r_cl_1042255002923493931'},
#    {'categoryId': '32',
#     'categoryName': '定番の魚料理',
#     'categoryUrl': 'https://recipe.rakuten.co.jp/category/32/?rafcid=wsc_r_cl_1042255002923493931'},
#    {'categoryId': '33',
#     'categoryName': '卵料理',
#     'categoryUrl': 'https://recipe.rakuten.co.jp/category/33/?rafcid=wsc_r_cl_1042255002923493931'},
#    {'categoryId': '14',
#     'categoryName': 'ご飯もの',
#     'categoryUrl': 'https://recipe.rakuten.co.jp/category/14/?rafcid=wsc_r_cl_1042255002923493931'},
#    {'categoryId': '15',
#     'categoryName': 'パスタ',
#     'categoryUrl': 'https://recipe.rakuten.co.jp/category/15/?rafcid=wsc_r_cl_1042255002923493931'},
# ...

# %%
# ステータスを表示
# 変数だけを指定する事でprint()を省略できます。
res
# Out:
# <Response [200]>

# %% [markdown]
# #楽天レシピカテゴリ別ランキングAPI

# %%
# アクセス先を指定。
# アクセス先を指定する必要があるので、アクセス先をREQUEST_URLという変数に代入しておきます。
REQUEST2_URL = 'https://app.rakuten.co.jp/services/api/Recipe/CategoryRanking/20170426?'


# 認証IDを指定
# アクセスを許可されたユーザーという事を証明するために、APP_IDに認証IDを代入しておきます。
APP_ID = "1042255002923493931"

# アクセス先と認証を用意できたので、なんのデータが欲しいか（要求するデータの）をparamsに代入しておきます。
# paramsでの指定方法はAPIの作成者によって変わりますので、事前に確認しておく必要があります。
params2 = {
    'format':'json',
    'applicationId': APP_ID    
}


# アクセス先と認証と要求するデータの内容を指定出来たので、次はrequestsのgetメソッドを使ってアクセスします。

# %%
# requestsのgetメソッドを使ってアクセス
# その結果をresに代入します。
res2 = requests.get(REQUEST2_URL, params2)

# 欲しいデータはresのjsonに格納されているので、res.json()をresultに代入しておきましょう。
result2 = res2.json()

# これでAPIで取得したデータはresultに代入されます。
result2
# Out:
# {'result': [{'foodImageUrl': 'https://image.space.rakuten.co.jp/d/strg/ctrl/3/b7127a3e32c2b2fa8b676ba390f30eb611c06f2c.45.2.3.2.jpg',
#    'mediumImageUrl': 'https://image.space.rakuten.co.jp/d/strg/ctrl/3/b7127a3e32c2b2fa8b676ba390f30eb611c06f2c.45.2.3.2.jpg?thum=54',
#    'nickname': 'ブルーボリジ',
#    'pickup': 0,
#    'rank': '1',
#    'recipeCost': '500円前後',
#    'recipeDescription': '漬けて一週間待つだけ、青々のパリパリのままで半年保存可能の胡瓜漬けです。2Ｋｇといわず3～4kg漬けても、あっという間に萎んでコンパクトになります。',
#    'recipeId': 1460004293,
#    'recipeIndication': '約30分',
#    'recipeMaterial': ['キュウリ', '塩（下漬け用）', '☆ザラメ', '☆酢'],
#    'recipePublishday': '2013/05/26 14:35:27',
#    'recipeTitle': '半年保存しても青々パリパリ☆胡瓜のパリパリ漬',
#    'recipeUrl': 'https://recipe.rakuten.co.jp/recipe/1460004293/?rafcid=wsc_r_cr_1042255002923493931',
#    'shop': 0,
#    'smallImageUrl': 'https://image.space.rakuten.co.jp/d/strg/ctrl/3/b7127a3e32c2b2fa8b676ba390f30eb611c06f2c.45.2.3.2.jpg?thum=55'},
# ...

# %%
i=0
print(result2["result"][i]["foodImageUrl"])
# Out:
# https://image.space.rakuten.co.jp/d/strg/ctrl/3/b7127a3e32c2b2fa8b676ba390f30eb611c06f2c.45.2.3.2.jpg
